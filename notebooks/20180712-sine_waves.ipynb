# %%
import matplotlib.pyplot as plt
import numpy as np


# %matplotlib inline

# %% [markdown]
# In this notebook, I'm beginning to explore the analog signals by plotting sine and cosine waves, with the intentions of building more complex signals in future notebooks.

# %%
# Create figure
fig = plt.figure()
# Define sampling frequency of 1000 Hz
freq_samp = 1000
# Define duration of time series = 1 second
duration = 1
# Define our time base, with steps of sampling frequency
time_base = np.linspace(0, dur, freq_samp * duration)
# Define signal frequency as 2 Hz
freq = 2
# Define our sine wave
sinW = np.sin(2*np.pi*freq*time_base)
# Define a cosine wave
cosW = np.cos(2*np.pi*freq*time_base)
# Create subplot
ax=plt.subplot(2,1,1)
# Plot sine wave across time_base, as a thick black line 
ax.plot(time_base, sinW, c='k',lw=4)
# Open second lower subplot
ax=plt.subplot(2,1,2)
# Plot cosine wave across time_base
ax.plot(time_base,cosW,c='k',lw=4)
